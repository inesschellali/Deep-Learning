# %%
import os
import pandas as pd
import mne

# %%
data_files = 'chb01'
files = os.listdir(data_files)
files
# Out:
# ['chb01_26.edf.seizures',
#  'chb01_21.edf.seizures',
#  'chb01_03.edf.seizures',
#  'chb01_04.edf.seizures',
#  '.DS_Store',
#  'chb01_16.edf.seizures',
#  'chb01_01.edf',
#  'chb01_15.edf',
#  'chb01_03.edf',
#  'chb01_16.edf',
#  'chb01_02.edf',
#  'chb01_18.edf.seizures',
#  'chb01_04.edf',
#  '.ipynb_checkpoints',
#  'SUBJECT-INFO',
#  'chb01-summary.txt',
#  'chb01_15.edf.seizures']

# %%
dfs = {}
for file in os.listdir(data_files):
    if file.endswith('.edf'):
        file_path = os.path.join(data_files, file)
        dfs[file] = mne.io.read_raw_edf(file_path, preload = True, verbose = False)
# Out:
# /var/folders/01/ydn5x7451959gqbpnwvby9hw0000gp/T/ipykernel_8584/2939079314.py:5: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   dfs[file] = mne.io.read_raw_edf(file_path, preload = True, verbose = False)
# /var/folders/01/ydn5x7451959gqbpnwvby9hw0000gp/T/ipykernel_8584/2939079314.py:5: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   dfs[file] = mne.io.read_raw_edf(file_path, preload = True, verbose = False)
# /var/folders/01/ydn5x7451959gqbpnwvby9hw0000gp/T/ipykernel_8584/2939079314.py:5: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   dfs[file] = mne.io.read_raw_edf(file_path, preload = True, verbose = False)
# ...

# %%
dfs['chb01_01.edf']
raw1 = mne.io.read_raw_edf('chb01/chb01_01.edf', preload=True, verbose=False)
raw1.plot()
# Out:
# /var/folders/01/ydn5x7451959gqbpnwvby9hw0000gp/T/ipykernel_8584/2457678872.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw1 = mne.io.read_raw_edf('chb01/chb01_01.edf', preload=True, verbose=False)
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1122.22x948.611 with 4 Axes>
# <MNEBrowseFigure size 1122.22x948.611 with 4 Axes>

# %%
raw1.ch_names
# Out:
# ['FP1-F7',
#  'F7-T7',
#  'T7-P7',
#  'P7-O1',
#  'FP1-F3',
#  'F3-C3',
#  'C3-P3',
#  'P3-O1',
#  'FP2-F4',
#  'F4-C4',
#  'C4-P4',
#  'P4-O2',
#  'FP2-F8',
#  'F8-T8',
#  'T8-P8-0',
#  'P8-O2',
#  'FZ-CZ',
#  'CZ-PZ',
#  'P7-T7',
#  'T7-FT9',
#  'FT9-FT10',
#  'FT10-T8',
#  'T8-P8-1']

# %%
channel = 'FP1-F7'
raw1.plot(start=1000, duration= 3, picks=[channel])
# Out:
# <MNEBrowseFigure size 1122.22x948.611 with 4 Axes>
# <MNEBrowseFigure size 1122.22x948.611 with 4 Axes>

# %%
# Power Spectral Density
raw1.plot_psd(fmax=60)
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.000 (s)
# Plotting power spectral density (dB=True).
# /var/folders/01/ydn5x7451959gqbpnwvby9hw0000gp/T/ipykernel_8584/3825993880.py:2: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw1.plot_psd(fmax=60)
# /opt/anaconda3/lib/python3.12/site-packages/mne/viz/utils.py:160: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
raw1.pick_channels(raw.ch_names[:5]).plot(duration=5)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <MNEBrowseFigure size 1122.22x948.611 with 4 Axes>
# <MNEBrowseFigure size 1122.22x948.611 with 4 Axes>
